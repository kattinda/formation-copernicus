# %% [markdown]
# # TD de Machine Learning : `Prédiction de la Note moyenne des livres`
# ### Exercice 1 :
# Les données d'entrées sont sauvegardées dans l'index `books` sur Elasticsearch.
# Créer une base de données d'entraînement et de test.
# Vous enregistrerez la base d'entraînement dans un index d'elasticsearch, qui portera le nom suivant :
#
# - `uppa_2025_train_nom_prenom`
#
#
# ### Exercice 2 :
# Créer un modèle `more_like_this` pour la prédiction de la note moyenne du livre (`average_rating`)
#
# ### Exercice 3 :
# Créer un modèle `more_like_this` par langue pour la prédiction de la note moyenne du livre (`average_rating`). Vous devrez dans un premier temps identifier la langue de chaque livre.

# %% [markdown]
# ## Installation des librairies

# %%
# !pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-8.15.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting elastic-transport<9,>=8.13 (from elasticsearch)
#   Downloading elastic_transport-8.15.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.13->elasticsearch) (2.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.13->elasticsearch) (2024.8.30)
# Downloading elasticsearch-8.15.1-py3-none-any.whl (524 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.6/524.6 kB 8.0 MB/s eta 0:00:00
# Downloading elastic_transport-8.15.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.15.1 elasticsearch-8.15.1

# %%
# !pip install elasticsearch-dsl

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=2d5f97ebe1d0254253fab764e59189162c07b2187f3ab02347f608febd8d3d34
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=3ad819a8b82c3d59b0de2959c2345c60ec6a77d2efc531dfc5b5f25de467c8f0
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %% [markdown]
# ## Importation des librairies

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
from elasticsearch_dsl import Search
import pandas as pd
import numpy as np
from langdetect import detect
import wget
from google.colab import drive
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 150)

# %% [markdown]
# # Exercice 1

# %%
# @title **Connexion à Elasticsearch**

es = Elasticsearch(
    hosts=['http://formakuntza-kibana.hupi.io:9200/'],
    basic_auth=('student', 'gCzOD2pVnCqVpd13')
)

# Tester la connexion :
print(es.info())
# Out:
# <ipython-input-154-51dbcd876948>:1: DeprecationWarning: The 'http_auth' parameter is deprecated. Use 'basic_auth' or 'bearer_auth' parameters instead
#   es = Elasticsearch(
# {'name': 'instance-0000000000', 'cluster_name': '1b2852bea18b4caa8a6e28ec5c6795d0', 'cluster_uuid': '-AjNWCALS2yUXAuZXkVCog', 'version': {'number': '8.15.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '98adf7bf6bb69b66ab95b761c9e5aadb0bb059a3', 'build_date': '2024-09-19T10:06:03.564235954Z', 'build_snapshot': False, 'lucene_version': '9.11.1', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %%
# @title **Lecture de l'index "books" comme les données d'entrées**

# @title **Afficher l'index "ecommerce"**
index_name = "books"

s = Search(using=es, index=index_name).query("match_all")

# Utilisation de la méthode scan pour récupérer tous les résultats rapidement
results = s.scan()

# Convertir les résultats en DataFrame
data = [hit.to_dict() for hit in results]
df = pd.json_normalize(data)

# Explorer les données
print(f"Show dataframe shape: {df.shape}")
print(f"Show dataframe first 10 rows: \n {df.head()}")
# Out:
#           isbn13      isbn10         title subtitle  \
# 0  9780002005883  0002005883        Gilead      NaN
# 1  9780002261982  0002261987  Spider's Web  A Novel
# 2  9780006163831  0006163831  The One Tree      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  Volume Two of Stephen Donaldson's acclaimed se...          1982.0
#
#    average_rating  num_pages  ratings_count  id_book
# 0            3.85      247.0          361.0        1
# 1            3.83      241.0         5164.0        2
# 2            3.97      479.0          172.0        3

# %% [markdown]
# ## Diviser les données en ensembles d'entraînement (80%) et de test (20%)

# %%
# Diviser les données en ensembles d'entraînement (80%) et de test (20%)
train_df, test_df = # A compléter
print(f"Taille de l'ensemble d'entraînement (train_df) : {train_df.shape}")
print(f"Taille de l'ensemble de test (test_df) : {test_df.shape}")
# Out:
# Taille de l'ensemble d'entraînement (train_df) : (5448, 13)
# Taille de l'ensemble de test (test_df) : (1362, 13)

# %% [markdown]
# ## Ecriture des données dans elasticsearch

# %%
index_name = 'uppa_2025_train_nom_prenom' # A MODIFIER

# Mapping for the index (modify according to your data structure)
mapping = # A compléter

# Create the index with the specified mapping
# A compléter
# Out:
# <ipython-input-157-5d756e7ade22>:21: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.create(index=index_name, body=mapping, ignore=400)
# ObjectApiResponse({'error': {'root_cause': [{'type': 'mapper_parsing_exception', 'reason': 'No handler for type [int] declared on field [id_book]'}], 'type': 'mapper_parsing_exception', 'reason': 'Failed to parse mapping: No handler for type [int] declared on field [id_book]', 'caused_by': {'type': 'mapper_parsing_exception', 'reason': 'No handler for type [int] declared on field [id_book]'}}, 'status': 400})

# %%
def df_to_es(df):
    for record in df.to_dict(orient='records'):
        yield {
            "_index": index_name,
            "_source": record
        }

# Bulk insert the data into Elasticsearch
df_to_index = # A compléter
success, failed = # A compléter  # Set raise_on_error to False

# Print the result
print(f"Successfully indexed {success} documents.")
print(f"Failed to index {failed} documents.")

# Print details of failed documents
for item in failed:
    print(f"Failed document: {item}")
# Out:
# Successfully indexed 5119 documents.
# Failed to index [] documents.

# %% [markdown]
# # Exercice 2 :
# Prédiction de la note moyenne des livres
#
# ### Question 1 :
# Calculer un score pour un livre que vous auriez choisi.
# L'objectif est de prendre en main la requête `more_like_this`
#
# ### Question 2 :
# Créer un modèle sur la base d'entraînement de `train_df` que vous testerez pour l'ensemble des livres présents dans `test_df`. Vous mettrez également en place des métriques afin d'évaluer et améliorer vos différents modèles.
#
# ### Question 3 :
# Créer un modèle par langue sur la base d'entraînement de `train_df` que vous testerez pour l'ensemble des livres présents dans `test_df`. Vous mettrez également en place des métriques afin d'évaluer et améliorer vos différents modèles.

# %% [markdown]
# ## Question 1 : Détection des similarités avec `more_like_this`
# Documentation : https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-mlt-query.html

# %%
###############################################   Select an item for evaluation

response = # A compléter

print(f"Response: {response} \n")
hits = # A compléter
source_list = # A compléter
df = # A compléter
print(f"Dataframe view: \n{df}")
# Out:
# Response: {'took': 1, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_shard': '[books_index][0]', '_node': '4Auo0ZvbTNWkw58ClqENLQ', '_index': 'books_index', '_id': 'bqqUcZIBDDcGfhtK2z8z', '_score': 1.0, '_ignored': ['description.keyword'], '_source': {'id_book': 6603, 'title': 'The Gods Themselves', 'authors': 'Isaac Asimov', 'categories': 'Science fiction', 'description': 'In the year 2100, mankind on Earth, settlers in a lunar colony and aliens from the para-universe, a strange universe parallel in time to our own, are faced with a race against time to prevent total destruction of the Earth. The invention of the Inter-Universe Electron Pump has threatened the rate of hydrogen fusion in the sun, leading, inevitably, to the possibilty of a vast explosion -- and the vapourisation of the Earth exactly eight minutes later . . .', 'published_year': 2000.0, 'average_rating': 4.09, 'num_pages': 288.0, 'ratings_count': 41304.0}, '_explanation': {'value': 1.0, 'description': '_id:([6e aa 94 71 92 1 c 37 6 7e 1b 4a db 3f 33])', 'details': []}}]}}
#
# Dataframe view:
#    id_book                title       authors       categories  \
# 0     6603  The Gods Themselves  Isaac Asimov  Science fiction
#
#                                          description  published_year  \
# 0  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#    average_rating  num_pages  ratings_count
# 0            4.09      288.0        41304.0

# %%
df["description"].iloc[0] # to copy the content of the description
# Out:
# 'In the year 2100, mankind on Earth, settlers in a lunar colony and aliens from the para-universe, a strange universe parallel in time to our own, are faced with a race against time to prevent total destruction of the Earth. The invention of the Inter-Universe Electron Pump has threatened the rate of hydrogen fusion in the sun, leading, inevitably, to the possibilty of a vast explosion -- and the vapourisation of the Earth exactly eight minutes later . . .'

# %%
###############################################   Apply the more_like_this function

response = # A compléter

print(f"Response: {response} \n")
hits = # A compléter
source_list = # A compléter
df = # A compléter
print(f"Dataframe view: \n{df}")
# Out:
# Response: {'took': 9, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4971, 'relation': 'eq'}, 'max_score': 18.599382, 'hits': [{'_shard': '[books_index][0]', '_node': '4Auo0ZvbTNWkw58ClqENLQ', '_index': 'books_index', '_id': 'bqqUcZIBDDcGfhtK2z8z', '_score': 18.599382, '_ignored': ['description.keyword'], '_source': {'id_book': 6603, 'title': 'The Gods Themselves', 'authors': 'Isaac Asimov', 'categories': 'Science fiction', 'description': 'In the year 2100, mankind on Earth, settlers in a lunar colony and aliens from the para-universe, a strange universe parallel in time to our own, are faced with a race against time to prevent total destruction of the Earth. The invention of the Inter-Universe Electron Pump has threatened the rate of hydrogen fusion in the sun, leading, inevitably, to the possibilty of a vast explosion -- and the vapourisation of the Earth exactly eight minutes later . . .', 'published_year': 2000.0, 'average_rating': 4.09, 'num_pages': 288.0, 'ratings_count': 41304.0}, '_explanation': {'value': 18.599382, 'description': 'sum of:', 'details': [{'value': 0.23543184, 'description': 'weight(description:and in 0) [PerFieldSimilarity], result of:', 'details': [{'value': 0.23543184, 'description': 'score(freq=2.0), computed as boost * idf * tf from:', 'details': [{'value': 2.2, 'description': 'boost', 'details': []}, {'value': 0.17729318, 'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:', 'details': [{'value': 4286, 'description': 'n, number of documents containing term', 'details': []}, {'value': 5117, 'description': 'N, total number of documents with field', 'details': []}]}, {'value': 0.6036017, 'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:', 'details': [{'value': 2.0, 'description': 'freq, occurrences of term within document', 'details': []}, {'value': 1.2, 'description': 'k1, term saturation parameter', 'details': []}, {'value': 0.75, 'description': 'b, length normalization parameter', 'details': []}, {'value': 76.0, 'description': 'dl, length of field (approximate)', 'details': []}, {'value': 67.49267, 'description': 'avgdl, average length of field', 'details': []}]}]}]}, {'value': 0.7298329, 'description': 'weight(description:to in 0) [PerFieldSimilarity], result of:', 'details': [{'value': 0.7298329, 'description': 'score(freq=3.0), computed as boost * idf * tf from:', 'details': [{'value': 2.2, 'description': 'boost', 'details': []}, {'value': 0.4769838, 'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:', 'details': [{'value': 3176, 'description': 'n, number of documents containing term', 'details': []}, {'value': 5117, 'description': 'N, total number of documents with field', 'details': []}]}, {'value': 0.6955, 'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:', 'details': [{'value': 3.0, 'description': 'freq, occurrences of term within document', 'details': []}, {'value': 1.2, 'description': 'k1, term saturation parameter', 'details': []}, {'value': 0.75, 'description': 'b, length normalization parameter', 'details': []}, {'value': 76.0, 'description': 'dl, length of field (approximate)', 'details': []}, {'value': 67.49267, 'description': 'avgdl, average length of field', 'details': []}]}]}]}, {'value': 0.48727417, 'description': 'weight(description:a in 0) [PerFieldSimilarity], result of:', 'details': [{'value': 0.48727417, 'description': 'score(freq=4.0), computed as boost * idf * tf from:', 'details': [{'value': 2.2, 'description': 'boost', 'details': []}, {'value': 0.29421633, 'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:', 'details': [{'value': 3813, 'description': 'n, number of documents containing term', 'details': []}, {'value': 5117, 'description': 'N, total number of documents with field', 'details': []}]}, {'value': 0.7528075, 'description': 'tf, computed as freq / (freq + k1 *  ...
#
# Dataframe view:
#    id_book                       title                             authors  \
# 0     6603         The Gods Themselves                        Isaac Asimov
# 1     6560  The Future of the Universe                        A.J. Meadows
# 2     1784         The Dragons of Eden                          Carl Sagan
# 3     1581    Tales of the Dying Earth                          Jack Vance
# 4     1708     A Second Chance at Eden                   Peter F. Hamilton
# 5     3470     A Brief History of Time                     Stephen Hawking
# 6      897                    Sammlung  Jorge Luis Borges;Eliot Weinberger
# 7     4750          Terraforming Earth                     Jack Williamson
# 8     3263         Two Complete Novels                       Douglas Adams
# 9      878    The Fabric of the Cosmos                        Brian Greene
#
#                                 categories  \
# 0                          Science fiction
# 1                                  Science
# 2                                   Nature
# 3                                  Fiction
# 4                          Science fiction
# 5                                  Science
# 6                     Argentine literature
# 7                                  Fiction
# 8  Detective and mystery stories, English.
# 9                                  Science
#
#                                          description  published_year  \
# 0  In the year 2100, mankind on Earth, settlers i...          2000.0
# 1  Many books have described how the universe bec...          2007.0
# 2  The well-known astronomer and astrobiologist s...          1977.0
# 3  A first-time compilation of a classic science ...          2000.0
# 4  This novella and six stories are set in the sa...          1999.0
# 5  An anniversary edition of a now-classic survey...          1998.0
# 6  Though best known in the English speaking worl...          1999.0
# 7  First Paperback, Contains the Hugo and Nebula ...          2003.0
# 8  Following themes of zany space exploration, ti...          1987.0
# 9  From the bestselling author of The Elegant Uni...          2005.0
#
#    average_rating  num_pages  ratings_count
# 0            4.09      288.0        41304.0
# 1            3.75      175.0            4.0
# 2            4.17      271.0        14974.0
# 3            4.14      741.0         3919.0
# 4            4.02      496.0         3844.0
# 5            4.16      212.0       214520.0
# 6            4.54      560.0          156.0
# 7            3.47      352.0           16.0
# 8            4.18      436.0          238.0
# 9            4.12      592.0          324.0

# %%
# explanation of similarities
response["hits"]["hits"]
# Out:
# [{'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': 'C_13cZIB5gnEiKXDfa-x',
#   '_score': 18.599382,
#   '_source': {'title': 'The Gods Themselves',
#    'authors': 'Isaac Asimov',
#    'categories': 'Science fiction',
#    'description': 'In the year 2100, mankind on Earth, settlers in a lunar colony and aliens from the para-universe, a strange universe parallel in time to our own, are faced with a race against time to prevent total destruction of the Earth. The invention of the Inter-Universe Electron Pump has threatened the rate of hydrogen fusion in the sun, leading, inevitably, to the possibilty of a vast explosion -- and the vapourisation of the Earth exactly eight minutes later . . .',
#    'published_year': 2000.0,
#    'average_rating': 4.09,
#    'num_pages': 288.0,
#    'ratings_count': 41304.0},
#   '_explanation': {'value': 18.599382,
#    'description': 'sum of:',
#    'details': [{'value': 0.23543184,
#      'description': 'weight(description:and in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.23543184,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6036017,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.7298329,
#      'description': 'weight(description:to in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.7298329,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6955,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.48727417,
#      'description': 'weight(description:a in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.48727417,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7528075,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.30078998,
#      'description': 'weight(description:of in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.30078998,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.79196084,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.859719,
#      'description': 'weight(description:in in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.859719,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7528075,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 3.1331933,
#      'description': 'weight(description:time in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 3.1331933,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.3594677,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 483,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6036017,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.22597867,
#      'description': 'weight(description:the in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.22597867,
#        'description': 'score(freq=10.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.8839042,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 10.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 5.9108195,
#      'description': 'weight(description:earth in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 5.9108195,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8630283,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 107,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6955,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 6.7163424,
#      'description': 'weight(description:universe in 0) [PerFieldSimilarity], result of:',
#      'details': [{'value': 6.7163424,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 4.389479,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 63,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6955,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 76.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': '5f13cZIB5gnEiKXDfa-x',
#   '_score': 15.426851,
#   '_source': {'title': 'The Future of the Universe',
#    'authors': 'A.J. Meadows',
#    'categories': 'Science',
#    'description': 'Many books have described how the universe became the way it is today. But what about the future of the universe? How long might the universe as we recognize it survive? The Future of the Universe takes the reader on a journey through space and time, beginning with a long look at the Earth and solar system, voyaging to the outermost galaxies, and finishing with speculations about the life and fate of the entire universe.',
#    'published_year': 2007.0,
#    'average_rating': 3.75,
#    'num_pages': 175.0,
#    'ratings_count': 4.0},
#   '_explanation': {'value': 15.426851,
#    'description': 'sum of:',
#    'details': [{'value': 0.2966063,
#      'description': 'weight(description:and in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.2966063,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7604412,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.46429908,
#      'description': 'weight(description:to in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.46429908,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.44245744,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.3970891,
#      'description': 'weight(description:a in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.3970891,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6134773,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.26746112,
#      'description': 'weight(description:of in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.26746112,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7042081,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.296721,
#      'description': 'weight(description:time in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.296721,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.3594677,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 483,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.44245744,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.23136443,
#      'description': 'weight(description:the in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.23136443,
#        'description': 'score(freq=12.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.9049702,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 12.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 3.7602963,
#      'description': 'weight(description:earth in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 3.7602963,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8630283,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 107,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.44245744,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 7.713014,
#      'description': 'weight(description:universe in 218) [PerFieldSimilarity], result of:',
#      'details': [{'value': 7.713014,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 4.389479,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 63,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.79870874,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 72.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': 'Av13cZIB5gnEiKXDgLmw',
#   '_score': 11.625924,
#   '_source': {'title': 'The Dragons of Eden',
#    'authors': 'Carl Sagan',
#    'categories': 'Nature',
#    'description': 'The well-known astronomer and astrobiologist surveys current knowledge of the development of intelligence on Earth in various forms of life and explains his persuasion that intelligence must have developed along similar lines throughout the universe',
#    'published_year': 1977.0,
#    'average_rating': 4.17,
#    'num_pages': 271.0,
#    'ratings_count': 14974.0},
#   '_explanation': {'value': 11.625924,
#    'description': 'sum of:',
#    'details': [{'value': 0.28060263,
#      'description': 'weight(description:and in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.28060263,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7194109,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.30142766,
#      'description': 'weight(description:of in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.30142766,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.79363984,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.6415637,
#      'description': 'weight(description:in in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.6415637,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5617812,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.20290172,
#      'description': 'weight(description:the in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.20290172,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.79363984,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 4.774389,
#      'description': 'weight(description:earth in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 4.774389,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8630283,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 107,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5617812,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 5.42504,
#      'description': 'weight(description:universe in 51) [PerFieldSimilarity], result of:',
#      'details': [{'value': 5.42504,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 4.389479,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 63,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5617812,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 36.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': '4_13cZIB5gnEiKXDfbCx',
#   '_score': 11.3350315,
#   '_source': {'title': 'Tales of the Dying Earth',
#    'authors': 'Jack Vance',
#    'categories': 'Fiction',
#    'description': "A first-time compilation of a classic science fiction series gathers all four books of The Dying Earth series--The Dying Earth, The Eyes of the Overworld, Cugel's Saga, and Rialto the Magnificent--in which Earth, in the distant future, tries to survive the approaching death of its red sun. Reprint. 12,500 first printing.",
#    'published_year': 2000.0,
#    'average_rating': 4.14,
#    'num_pages': 741.0,
#    'ratings_count': 3919.0},
#   '_explanation': {'value': 11.3350315,
#    'description': 'sum of:',
#    'details': [{'value': 0.1930841,
#      'description': 'weight(description:and in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.1930841,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.49503028,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.5194672,
#      'description': 'weight(description:to in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.5194672,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.49503028,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.42864844,
#      'description': 'weight(description:a in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.42864844,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6622345,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.30262804,
#      'description': 'weight(description:of in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.30262804,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7968003,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.75628304,
#      'description': 'weight(description:in in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.75628304,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6622345,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.5696177,
#      'description': 'weight(description:time in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.5696177,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.3594677,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 483,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.49503028,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.22314219,
#      'description': 'weight(description:the in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.22314219,
#        'description': 'score(freq=7.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.8728094,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 7.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 6.342161,
#      'description': 'weight(description:earth in 472) [PerFieldSimilarity], result of:',
#      'details': [{'value': 6.342161,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8630283,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 107,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7462541,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 54.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': 'KP13cZIB5gnEiKXDgsKf',
#   '_score': 10.799385,
#   '_source': {'title': 'A Second Chance at Eden',
#    'authors': 'Peter F. Hamilton',
#    'categories': 'Science fiction',
#    'description': "This novella and six stories are set in the same universe and time-line as the Night's Dawn trilogy.",
#    'published_year': 1999.0,
#    'average_rating': 4.02,
#    'num_pages': 496.0,
#    'ratings_count': 3844.0},
#   '_explanation': {'value': 10.799385,
#    'description': 'sum of:',
#    'details': [{'value': 0.305515,
#      'description': 'weight(description:and in 2393) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.305515,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7832814,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
# ...
#            'details': []}]}]}]},
#     {'value': 0.22014117,
#      'description': 'weight(description:the in 2365) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.22014117,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.86107105,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 38.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 5.3449597,
#      'description': 'weight(description:universe in 2365) [PerFieldSimilarity], result of:',
#      'details': [{'value': 5.3449597,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 4.389479,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 63,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.55348873,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 38.0, 'description': 'dl, length of field', 'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[books_index][0]',
#   '_node': '4Auo0ZvbTNWkw58ClqENLQ',
#   '_index': 'books_index',
#   '_id': 'Af13cZIB5gnEiKXDfbCx',
#   '_score': 9.77947,
#   '_source': {'title': 'The Fabric of the Cosmos',
#    'authors': 'Brian Greene',
#    'categories': 'Science',
#    'description': "From the bestselling author of The Elegant Universe, Brian Greene's The Fabric of the Cosmos takes us on an irresistible and revelatory journey through the biggest of the big questions. What is reality? Could we exist without space and time? Can we travel to the past? What are the limits of the universe? Brian Greene has made the mysteries of space and time accessible to millions with his acclaimed writings and award-winning TV series. Now he reveals a world more beautiful and bizarre than we could have imagined, where 'dark matter' reigns, space warps and wiggles through eleven dimensions, minute particles dance, fizz and teleport across vast distances, everything is made of vibrating strings and, like an ant on a lily-pad, we may be floating on a sliver of spacetime. Revealing new layers of reality that lie just beneath the surface of our everyday lives, this grand tour of the universe will make you look at the world in a completely new way. 'A must-read' Sunday Times 'Greene takes us to the limits of space and time' Guardian 'Sends the reader's imagination hurtling through the universe on an astonishing ride' The New York Times Brian Greene is well known to many fans as a populariser of theoretical physics. He is the author of the bestselling books about string theory, The Elegant Universe, which was a finalist for the Pulitzer Prize for nonfiction, The Fabric of the Cosmos, and The Hidden Reality. Educated at Harvard and Oxford, he has taught at both Harvard and Cornell and has been Professor of Physics and Mathematics at Columbia University since 1996.",
#    'published_year': 2005.0,
#    'average_rating': 4.12,
#    'num_pages': 592.0,
#    'ratings_count': 324.0},
#   '_explanation': {'value': 9.77947,
#    'description': 'sum of:',
#    'details': [{'value': 0.3064261,
#      'description': 'weight(description:and in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.3064261,
#        'description': 'score(freq=14.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.78561723,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 14.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.53673303,
#      'description': 'weight(description:to in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.53673303,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.51148397,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.41874042,
#      'description': 'weight(description:a in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.41874042,
#        'description': 'score(freq=7.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.64692724,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 7.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.30270702,
#      'description': 'weight(description:of in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.30270702,
#        'description': 'score(freq=15.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7970083,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 15.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.23691422,
#      'description': 'weight(description:in in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.23691422,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.20745242,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.283228,
#      'description': 'weight(description:time in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.283228,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.3594677,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 483,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.43985802,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.2205517,
#      'description': 'weight(description:the in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.2205517,
#        'description': 'score(freq=24.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.86267686,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 24.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 5.47417,
#      'description': 'weight(description:universe in 246) [PerFieldSimilarity], result of:',
#      'details': [{'value': 5.47417,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 4.389479,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 63,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5668689,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 264.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}}]

# %% [markdown]
# Le livre le plus similaire selon le contenu, l'auteur et le titre est le livre "The Future of the Universe" qui est noté à 3.75. Nous aurions donc fait une erreur de : 4.09 - 3.75 = 0.34

# %% [markdown]
# ### Correction : pour aller plus loin
# Recherche des termes avec un second modèle `multi_match`
# Documentation : https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-multi-match-query.html

# %%
###############################################    Apply the multi_match function

response = # A compléter

print(response)
hits = # A compléter
source_list = # A compléter
df = # A compléter
print(df)
# Out:
# {'took': 6, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 5062, 'relation': 'eq'}, 'max_score': 271.19333, 'hits': [{'_index': 'books_index', '_id': 'bqqUcZIBDDcGfhtK2z8z', '_score': 271.19333, '_ignored': ['description.keyword'], '_source': {'id_book': 6603, 'title': 'The Gods Themselves', 'authors': 'Isaac Asimov', 'categories': 'Science fiction', 'description': 'In the year 2100, mankind on Earth, settlers in a lunar colony and aliens from the para-universe, a strange universe parallel in time to our own, are faced with a race against time to prevent total destruction of the Earth. The invention of the Inter-Universe Electron Pump has threatened the rate of hydrogen fusion in the sun, leading, inevitably, to the possibilty of a vast explosion -- and the vapourisation of the Earth exactly eight minutes later . . .', 'published_year': 2000.0, 'average_rating': 4.09, 'num_pages': 288.0, 'ratings_count': 41304.0}}, {'_index': 'books_index', '_id': 'SKqUcZIBDDcGfhtK20A0', '_score': 48.83166, '_ignored': ['description.keyword'], '_source': {'id_book': 6560, 'title': 'The Future of the Universe', 'authors': 'A.J. Meadows', 'categories': 'Science', 'description': 'Many books have described how the universe became the way it is today. But what about the future of the universe? How long might the universe as we recognize it survive? The Future of the Universe takes the reader on a journey through space and time, beginning with a long look at the Earth and solar system, voyaging to the outermost galaxies, and finishing with speculations about the life and fate of the entire universe.', 'published_year': 2007.0, 'average_rating': 3.75, 'num_pages': 175.0, 'ratings_count': 4.0}}, {'_index': 'books_index', '_id': '-aqUcZIBDDcGfhtK3EI5', '_score': 43.55677, '_ignored': ['description.keyword'], '_source': {'id_book': 3631, 'title': 'Worlds', 'authors': 'Joe Haldeman', 'categories': 'Fiction', 'description': 'Towards the end of the twenty-first century 41 Worlds, small satellites with a total population of half a million, orbit the Earth, which has seen many changes, not least of which is a second revolution in America. Marianne O¿Hara, a brilliant political sciences student, is from New New York, a hollowed out asteroid and the largest of the Worlds, but is to spend a year on Earth as a postgraduate student. Because the political relationship between the Worlds and Earth is complex and voltatile, Marianne unwittingly finds herself caught up with a group of fanatics determined on a third revolution in America - even if such a revolution could lead to the destruction of the Earth...', 'published_year': 2002.0, 'average_rating': 3.51, 'num_pages': 240.0, 'ratings_count': 39.0}}, {'_index': 'books_index', '_id': '_KqUcZIBDDcGfhtK3EPU', '_score': 40.449215, '_ignored': ['description.keyword'], '_source': {'id_book': 3128, 'title': "Stephen Hawking's Universe", 'authors': 'David Filkin', 'categories': 'Science', 'description': "Stephen Hawking's A Brief History of Time has sold over 9 million copies worldwide. Now, in everyday language, Stephen Hawking's Universe reveals step-by-step how we can all share his understanding of the cosmos, and our own place within it. Stargazing has never been the same since cosmologists discovered that galaxies are moving away from each other at an extraordinary speed. It was this understanding of the movement of galaxies that allowed scientists to develop a theory of how the universe was created—the Big Bang theory. Working with this theory, Stephen Hawking and other physicists felt challenged to come up with a scientific picture that would tackle the fundamental question: what is the nature of the universe? Stephen Hawking's Universe charts this work and provides simple explanations for phenomena that arouse our curiosity. This work is a voyage of discovery with an astonishing set of conclusions that will enable us to understand how matter ca ...
#    id_book                       title                             authors  \
# 0     6603         The Gods Themselves                        Isaac Asimov
# 1     6560  The Future of the Universe                        A.J. Meadows
# 2     3631                      Worlds                        Joe Haldeman
# 3     3128  Stephen Hawking's Universe                        David Filkin
# 4     1581    Tales of the Dying Earth                          Jack Vance
# 5      897                    Sammlung  Jorge Luis Borges;Eliot Weinberger
# 6     3465             Feersum Endjinn                          Iain Banks
# 7     1784         The Dragons of Eden                          Carl Sagan
# 8      878    The Fabric of the Cosmos                        Brian Greene
# 9     5705             Parallel Worlds                         Michio Kaku
#
#              categories                                        description  \
# 0       Science fiction  In the year 2100, mankind on Earth, settlers i...
# 1               Science  Many books have described how the universe bec...
# 2               Fiction  Towards the end of the twenty-first century 41...
# 3               Science  Stephen Hawking's A Brief History of Time has ...
# 4               Fiction  A first-time compilation of a classic science ...
# 5  Argentine literature  Though best known in the English speaking worl...
# 6               Fiction  Living the last of his eight lives, Count Alan...
# 7                Nature  The well-known astronomer and astrobiologist s...
# 8               Science  From the bestselling author of The Elegant Uni...
# 9               Science  Sheds new light on discoveries that have revol...
#
#    published_year  average_rating  num_pages  ratings_count
# 0          2000.0            4.09      288.0        41304.0
# 1          2007.0            3.75      175.0            4.0
# 2          2002.0            3.51      240.0           39.0
# 3          1998.0            4.28      304.0         1383.0
# 4          2000.0            4.14      741.0         3919.0
# 5          1999.0            4.54      560.0          156.0
# 6          1995.0            3.82      311.0          311.0
# 7          1977.0            4.17      271.0        14974.0
# 8          2005.0            4.12      592.0          324.0
# 9          2006.0            4.18      361.0        14613.0

# %% [markdown]
# ## Question 2

# %%
def get_similar_document(row):
    # Extraire les informations pertinentes de la ligne du dataframe
    title = # A compléter
    author = # A compléter
    description = # A compléter

    # Requête more_like_this pour Elasticsearch
    response = # A compléter

    # Récupérer les documents similaires
    hits = # A compléter

    if hits:
        # Extraire les informations du premier résultat le plus pertinent
        most_similar_doc = # A compléter
        # Renvoyer la valeur de la colonne 'average_rating'
        return most_similar_doc.get('average_rating', None)
    else:
        return None

# %%
test_df['similar_average_rating'] = # A compléter

# %%
# compute metrics
mae = # A compléter
print(f"Erreur absolue moyenne (MAE) : {mae}")

mse = # A compléter
print(f"Erreur quadratique moyenne (MSE) : {mse}")

rmse = # A compléter
print(f"Racine de l'erreur quadratique moyenne (RMSE) : {rmse}")
# Out:
# Erreur absolue moyenne (MAE) : 0.28680250783699063
# Erreur quadratique moyenne (MSE) : 0.17300156739811912
# Racine de l'erreur quadratique moyenne (RMSE) : 0.4159345710542935

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Détection de la langue

# %%
# Fonction pour détecter la langue d'un titre de livre
def detect_language(description):
    try:
        return detect(description)
    except:
        return 'unknown'

# %%
# Ajouter une colonne 'language' au DataFrame
train_df['language'] = # A compléter
test_df['language'] = # A compléter

# %%
train_df.head(2)
# Out:
#              isbn13      isbn10                title subtitle  \
# 4235  9780704102477  0704102471        The Egg and I      NaN
# 6602  9781857989342  1857989341  The Gods Themselves      NaN
#
#               authors       categories  \
# 4235  Betty MacDonald        Farm life
# 6602     Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 4235  http://books.google.com/books/content?id=W3dGP...
# 6602  http://books.google.com/books/content?id=8ClIP...
#
#                                             description  published_year  \
# 4235                                                NaN          1992.0
# 6602  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  id_book language
# 4235            3.93      288.0         6223.0     4236  unknown
# 6602            4.09      288.0        41304.0     6603       en

# %%
# Vérifier la distribution des langues
print(train_df['language'].value_counts())
# Out:
# language
# en         5198
# unknown     220
# de           11
# id            7
# nl            3
# da            2
# tl            2
# vi            1
# et            1
# it            1
# ja            1
# ro            1
# Name: count, dtype: int64

# %%
for index, row in train_df.iterrows():
    id_book = # A compléter # ID du document dans Elasticsearch
    language = # A compléter  # Langue à mettre à jour

    # Utiliser update_by_query pour mettre à jour le champ 'language'
    update_query = # A compléter

    # Exécuter la requête
    response = # A compléter

    print(f"Updated language for id_book {id_book}: {language}. Response: {response}")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Updated language for id_book 606: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1195: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2875: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2021: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2907: en. Response: {'took': 10, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4295: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1757: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 498: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2276: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3774: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6659: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3479: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6682: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3876: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 722: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3933: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1026: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4951: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1296: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3291: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1497: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2207: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1521: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4910: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4332: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1881: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2482: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6141: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3320: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2446: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6156: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4956: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1303: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 109: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4387: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1352: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6088: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2877: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3440: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5477: en. Response: {'took': 11, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 932: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 337: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5967: en. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2616: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4779: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5858: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 938: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6393: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1581: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4732: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 388: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4321: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5929: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3348: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2403: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3397: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 725: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 766: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 287: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5610: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6724: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 308: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4518: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1861: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3760: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2841: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2708: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5301: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3722: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2665: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6167: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1792: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3036: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2054: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1635: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2657: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4782: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5776: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 185: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3957: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 72: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5031: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 712: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 422: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1021: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2192: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3358: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3003: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 738: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5750: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1261: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1667: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2573: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5039: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2917: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3183: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6618: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6317: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6485: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3950: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2003: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1211: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1696: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3606: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6394: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1096: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3626: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6107: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4375: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1631: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3821: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1882: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3239: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4553: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1613: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 979: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2883: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4830: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1962: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6442: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 488: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6216: en. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5996: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 345: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2861: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6460: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6674: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2866: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 912: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1042: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 48: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3758: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5902: en. Response: {'took': 9, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1351: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 444: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3249: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1062: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1452: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1868: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4064: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3253: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1744: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5364: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6251: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3916: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1755: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4004: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3188: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4078: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2973: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1056: en. Response: {'took': 15, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 849: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3050: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3492: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2459: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4206: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1295: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# ...
# Updated language for id_book 2889: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6165: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 647: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3891: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3557: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3203: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1529: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1268: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1900: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4659: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3006: en. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2735: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 190: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1807: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 976: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2748: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2048: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2559: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1083: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 475: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2905: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4844: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6397: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4118: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3386: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4556: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1185: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6421: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5052: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5312: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2434: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5612: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2392: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 770: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 1686: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 131: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 2920: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3172: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3445: en. Response: {'took': 10, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6232: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5579: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 4427: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5335: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 467: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 6266: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5735: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3093: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 3773: unknown. Response: {'took': 0, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5192: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5227: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 5391: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 861: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}

# %% [markdown]
# ### Evaluation de la similarité

# %%
def get_similar_document_by_language(row):
    # Extraire les informations pertinentes de la ligne du dataframe
    title = # A compléter
    authors = # A compléter
    description = # A compléter
    language = # A compléter

    # Requête more_like_this pour Elasticsearch, en incluant un filtre sur la langue
    response = # A compléter

    # Récupérer les documents similaires
    hits = response['hits']['hits']

    if hits:
        # Extraire les informations du premier résultat le plus pertinent
        most_similar_doc = # A compléter
        # Renvoyer la valeur de la colonne 'average_rating'
        return most_similar_doc.get('average_rating', None)
    else:
        return None

# %%
test_df['lang_similar_average_rating'] = # A compléter

# Afficher le dataframe avec la nouvelle colonne 'lang_similar_average_rating'
print(test_df.head())
# Out:
#              isbn13      isbn10                                        title  \
# 1632  9780312994815  0312994818                                  The Firefly
# 3891  9780671823498  0671823493                               The Good Earth
# 2115  9780375725036  0375725032        Elect Mr. Robinson for a Better World
# 2404  9780393320923  0393320928  "What Do You Care what Other People Think?"
# 3260  9780517101353  0517101351    A New Collection of Three Complete Novels
#
#                                        subtitle  \
# 1632                                    A Novel
# 3891                                        NaN
# 2115                                        NaN
# 2404  Further Adventures of a Curious Character
# 3260                                        NaN
#
#                                       authors                 categories  \
# 1632                         P. T. Deutermann                    Fiction
# 3891                 Pearl Sydenstricker Buck                      China
# 2115                            Donald Antrim                    Fiction
# 2404  Richard Phillips Feynman;Ralph Leighton  BIOGRAPHY & AUTOBIOGRAPHY
# 3260                         Michael Crichton                    Fiction
#
#                                               thumbnail  \
# 1632  http://books.google.com/books/content?id=dTHrm...
# 3891  http://books.google.com/books/content?id=ozQ8R...
# 2115  http://books.google.com/books/content?id=E-GwA...
# 2404  http://books.google.com/books/content?id=LUrJI...
# 3260  http://books.google.com/books/content?id=HGrNS...
#
#                                             description  published_year  \
# 1632  According to the DC cops, the fiery destructio...          2004.0
# 3891  A story of a Chinese peasant and his passionat...          1958.0
# 2115  In a world marked by full-scale neighborhood w...          1993.0
# 2404  This two-part profile of the late Nobel Prize-...          2001.0
# 3260  Fans of Jurassic Park and Rising Sun, the book...          1994.0
#
#       average_rating  num_pages  ratings_count  id_book language  \
# 1632            3.76      528.0          301.0     1633       en
# 3891            3.98      260.0           54.0     3892       en
# 2115            3.67      185.0          795.0     2116       en
# 2404            4.27      256.0        15646.0     2405       en
# 3260            3.99      720.0          943.0     3261       en
#
#       lang_similar_average_rating
# 1632                         3.73
# 3891                         4.21
# 2115                         3.85
# 2404                         4.41
# 3260                         4.15

# %%
# compute metrics
mae = # A compléter
print(f"Erreur absolue moyenne (MAE) : {mae}")

mse = # A compléter
print(f"Erreur quadratique moyenne (MSE) : {mse}")

rmse = # A compléter
print(f"Racine de l'erreur quadratique moyenne (RMSE) : {rmse}")
# Out:
# Erreur absolue moyenne (MAE) : 0.28711917916337804
# Erreur quadratique moyenne (MSE) : 0.17635801104972376
# Racine de l'erreur quadratique moyenne (RMSE) : 0.41995001017945427
