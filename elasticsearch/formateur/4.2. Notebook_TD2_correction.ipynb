# %% [markdown]
# # TD de Machine Learning : `Prédiction de la Note moyenne des livres`
# ### Exercice 1 :
# Les données d'entrées sont sauvegardées dans l'index `books` sur Elasticsearch.
# Créer une base de données d'entraînement et de test.
# Vous enregistrerez la base d'entraînement dans un index d'elasticsearch, qui portera le nom suivant :
#
# - `uppa_2025_train_nom_prenom`
#
#
# ### Exercice 2 :
# Créer un modèle `more_like_this` pour la prédiction de la note moyenne du livre (`average_rating`)
#
# ### Exercice 3 :
# Créer un modèle `more_like_this` par langue pour la prédiction de la note moyenne du livre (`average_rating`). Vous devrez dans un premier temps identifier la langue de chaque livre.

# %% [markdown]
# ## Installation des librairies

# %%
# !pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.10/dist-packages (8.17.0)
# Requirement already satisfied: elastic-transport<9,>=8.15.1 in /usr/local/lib/python3.10/dist-packages (from elasticsearch) (8.17.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2024.12.14)

# %%
# !pip install elasticsearch-dsl
# Out:
# Requirement already satisfied: elasticsearch-dsl in /usr/local/lib/python3.10/dist-packages (8.17.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from elasticsearch-dsl) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from elasticsearch-dsl) (4.12.2)
# Requirement already satisfied: elasticsearch<9.0.0,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from elasticsearch-dsl) (8.17.0)
# Requirement already satisfied: elastic-transport<9.0.0,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from elasticsearch-dsl) (8.17.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9.0.0,>=8.0.0->elasticsearch-dsl) (2.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9.0.0,>=8.0.0->elasticsearch-dsl) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->elasticsearch-dsl) (1.17.0)

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)

# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.17.0)

# %% [markdown]
# ## Importation des librairies

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
from elasticsearch_dsl import Search
import pandas as pd
import numpy as np
from langdetect import detect
import wget
from google.colab import drive
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 150)

# %% [markdown]
# # Exercice 1

# %%
# @title **Connexion à Elasticsearch**

es = Elasticsearch(
    hosts=['http://formakuntza-kibana.hupi.io:9200/'],
    basic_auth=('student', 'gCzOD2pVnCqVpd13')
)

try:
    # Récupérer les informations du cluster
    info = es.info()

    # Afficher des informations intéressantes
    print(f"Connexion réussie au cluster : {info['cluster_name']}")
    print(f"Version d'Elasticsearch : {info['version']['number']}")

    # Afficher les indices existants
    indices = es.cat.indices(format="json")
    print(f"Nombre d'index dans le cluster : {len(indices)}")

except Exception as e:
    print(f"Erreur de connexion : {e}")
# Out:
# Connexion réussie au cluster : docker-cluster
# Version d'Elasticsearch : 7.17.24
# Nombre d'index dans le cluster : 11

# %%
# @title **Lecture de l'index "books" comme les données d'entrées**

# @title **Afficher l'index "ecommerce"**
index_name = "books"

s = Search(using=es, index=index_name).query("match_all")

# Utilisation de la méthode scan pour récupérer tous les résultats rapidement
results = s.scan()

# Convertir les résultats en DataFrame
data = [hit.to_dict() for hit in results]
df = pd.json_normalize(data)

# Explorer les données
print(f"Show dataframe shape: {df.shape}")
print(f"Show dataframe first 10 rows: \n {df.head()}")
# Out:
# Show dataframe shape: (6810, 12)
# Show dataframe first 10 rows:
#                                             thumbnail  published_year  num_pages                                        description  average_rating  \
# 0  http://books.google.com/books/content?id=KQZCP...          2004.0      247.0  A NOVEL THAT READERS and critics have been eag...            3.85
# 1  http://books.google.com/books/content?id=gA5GP...          2000.0      241.0  A new 'Christie for Christmas' -- a full-lengt...            3.83
# 2  http://books.google.com/books/content?id=OmQaw...          1982.0      479.0  Volume Two of Stephen Donaldson's acclaimed se...            3.97
# 3  http://books.google.com/books/content?id=FKo2T...          1993.0      512.0  A memorable, mesmerizing heroine Jennifer -- b...            3.93
# 4  http://books.google.com/books/content?id=XhQ5X...          2002.0      170.0  Lewis' work on the nature of love divides love...            4.15
#
#             title         isbn13   isbn10                     categories  ratings_count                          authors subtitle
# 0          Gilead  9780002005883  2005883                        Fiction          361.0               Marilynne Robinson      NaN
# 1    Spider's Web  9780002261982  2261987  Detective and mystery stories         5164.0  Charles Osborne;Agatha Christie  A Novel
# 2    The One Tree  9780006163831  6163831               American fiction          172.0             Stephen R. Donaldson      NaN
# 3  Rage of angels  9780006178736  6178731                        Fiction        29532.0                   Sidney Sheldon      NaN
# 4  The Four Loves  9780006280897  6280897                 Christian life        33684.0              Clive Staples Lewis      NaN

# %%
# @title **Diviser les données en ensembles d'entraînement (80%) et de test (20%)**
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
print(f"Taille de l'ensemble d'entraînement (train_df) : {train_df.shape}")
print(f"Taille de l'ensemble de test (test_df) : {test_df.shape}")
# Out:
# Taille de l'ensemble d'entraînement (train_df) : (5448, 12)
# Taille de l'ensemble de test (test_df) : (1362, 12)

# %%
# @title **Créer l'index pour les données d'entraînement dans Elasticsearch**
index_name = 'uppa_2025_train_dassance_kattin'

# Mapping for the index (modify according to your data structure)
mapping = {
    "mappings": {
        "properties": {
            "isbn13": {"type": "long"},
            "title": {"type": "text"},
            "authors": {"type": "text"},
            "categories": {"type": "keyword"},
            "description": {"type": "text"},
            "published_year": {"type": "long"},
            "average_rating": {"type": "double"},
            "num_pages": {"type": "long"},
            "ratings_count": {"type": "long"}
        }
    }
}

# Create the index with the specified mapping
response = (es.options(ignore_status=400)
              .indices.create(index=index_name, body=mapping))
print(response)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'uppa_2025_dassance_kattin'}

# %%
# @title **Ecriture des données d'entraînement dans Elasticsearch**

def df_to_es(df):
    for record in df.to_dict(orient='records'):
        yield {
            "_index": index_name,
            "_source": record
        }

# Bulk insert the data into Elasticsearch
col_train = ["isbn13", "title", "authors", "categories", "description", "published_year", "average_rating", "num_pages", "ratings_count"]
df_to_index = train_df[col_train].dropna()
success, failed = bulk(es, df_to_es(df_to_index), raise_on_error=False)  # Set raise_on_error to False

# Print the result
print(f"Successfully indexed {success} documents.")
print(f"Failed to index {failed} documents.")

# Print details of failed documents
for item in failed:
    print(f"Failed document: {item}")
# Out:
# Successfully indexed 5119 documents.
# Failed to index [] documents.

# %% [markdown]
# # Exercice 2 :
# Prédiction de la note moyenne des livres.
#
# ### Question 1 :
# Calculer un score pour un livre que vous auriez choisi.
# L'objectif est de prendre en main la requête `more_like_this`
#
# ### Question 2 :
# Créer un modèle sur la base d'entraînement de `train_df` que vous testerez pour l'ensemble des livres présents dans `test_df`. Vous mettrez également en place des métriques afin d'évaluer et améliorer vos différents modèles.
#
# ### Question 3 :
# Créer un modèle par langue sur la base d'entraînement de `train_df` que vous testerez pour l'ensemble des livres présents dans `test_df`. Vous mettrez également en place des métriques afin d'évaluer et améliorer vos différents modèles.

# %% [markdown]
# ## Question 1 : Détection des similarités avec `more_like_this`
# Documentation : https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-mlt-query.html

# %%
###############################################   Select an item for evaluation

response = es.search(index="uppa_2025_train_dassance_kattin", body={
    "query": {
        "match": {
            "isbn13": 9780002005883
        }
    },
    "explain": "true"
})

print(f"Response: {response} \n")
hits = response['hits']['hits']
source_list = [hit['_source'] for hit in hits]
df = pd.json_normalize(source_list)
print(f"Dataframe view: \n{df}")
# Out:
# Response: {'took': 1, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_shard': '[uppa_2025_dassance_kattin][0]', '_node': 'w4J3bTfdQgWTrMMKXDMARw', '_index': 'uppa_2025_dassance_kattin', '_type': '_doc', '_id': '7dCwT5QB5IuiTNqkUQzC', '_score': 1.0, '_source': {'isbn13': 9780002005883, 'title': 'Gilead', 'authors': 'Marilynne Robinson', 'categories': 'Fiction', 'description': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.', 'published_year': 2004.0, 'average_rating': 3.85, 'num_pages': 247.0, 'ratings_count': 361.0}, '_explanation': {'value': 1.0, 'description': 'isbn13:[9780002005883 TO 9780002005883]', 'details': []}}]}}
#
# Dataframe view:
#           isbn13   title             authors categories                                        description  published_year  average_rating  \
# 0  9780002005883  Gilead  Marilynne Robinson    Fiction  A NOVEL THAT READERS and critics have been eag...          2004.0            3.85
#
#    num_pages  ratings_count
# 0      247.0          361.0

# %%
df["description"].iloc[0] # to copy the content of the description
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
###############################################   Apply the more_like_this function

response = es.search(index="uppa_2025_train_dassance_kattin", body={
    "query": {
        "more_like_this": {
            "fields": ["title", "author", "description"],
            "like": "A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike."
        }
    },
    "explain": "true"
})

print(f"Response: {response} \n")
hits = response['hits']['hits']
source_list = [hit['_source'] for hit in hits]
df = pd.json_normalize(source_list)
print(f"Dataframe view: \n{df}")
# Out:
# Response: {'took': 219, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 3405, 'relation': 'eq'}, 'max_score': 44.67813, 'hits': [{'_shard': '[uppa_2025_dassance_kattin][0]', '_node': 'w4J3bTfdQgWTrMMKXDMARw', '_index': 'uppa_2025_dassance_kattin', '_type': '_doc', '_id': '7dCwT5QB5IuiTNqkUQzC', '_score': 44.67813, '_source': {'isbn13': 9780002005883, 'title': 'Gilead', 'authors': 'Marilynne Robinson', 'categories': 'Fiction', 'description': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.', 'published_year': 2004.0, 'average_rating': 3.85, 'num_pages': 247.0, 'ratings_count': 361.0}, '_explanation': {'value': 44.67813, 'description': 'sum of:', 'details': [{'value': 1.0242417, 'description': 'weight(description:that in 423) [PerFieldSimilarity], result of:', 'details': [{'value': 1.0242417, 'description': 'score(freq=2.0), computed as boost * idf * tf from:', 'details': [{'value': 2.2, 'description': 'boost', 'details': []}, {'value': 1.156219, 'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:', 'details': [{'value': 1610, 'description': 'n, number of documents containing term', 'details': []}, {'value': 5117, 'description': 'N, total number of documents with field', 'details': []}]}, {'value': 0.4026611, 'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:', 'details': [{'value': 2.0, 'description': 'freq, occurrences of term within document', 'details': []}, {'value': 1.2, 'description': 'k1, term saturation parameter', 'details': []}, {'value': 0.75, 'description': 'b, length normalization parameter', 'details': []}, {'value': 200.0, 'description': 'dl, length of field (approximate)', 'details': []}, {'value': 67.49267, 'description': 'avgdl, average length of field', 'details': []}]}]}]}, {'value': 0.5275877, 'description': 'weight(description:to in 423) [PerFieldSimilarity], result of:', 'details': [{'value': 0.5275877, 'description': 'score(freq=3.0), computed as boost * idf * tf from:', 'details': [{'value': 2.2, 'description': 'boost', 'details': []}, {'value': 0.4769838, 'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:', 'details': [{'value': 3176, 'description': 'n, number of documents containing term', 'details': []}, {'value': 5117, 'description': 'N, total number of documents with field', 'details': []}]}, {'value': 0.5027689, 'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:', 'details': [{'value': 3.0, 'description': 'freq, occurrences of term within document', 'details': []}, {'value': 1.2, 'description': 'k1, term saturation parameter', 'details': []}, {'value': 0.75, 'description': 'b, length normalization parameter', 'details': []}, {'value': 200.0, 'description': 'dl, length of field (approximate)', 'details': []}, {'value': 67.49267, 'descri ...
#
# Dataframe view:
#           isbn13                      title             authors                 categories                                        description  \
# 0  9780002005883                     Gilead  Marilynne Robinson                    Fiction  A NOVEL THAT READERS and critics have been eag...
# 1  9780684813639                 John Adams    David McCullough  Biography & Autobiography  In this powerful, epic biography, David McCull...
# 2  9780060916817  The Chaneysville Incident       David Bradley                    History  The legends say something happened in Chaneysv...
# 3  9780870679940                   Whoreson       Donald Goines                    Fiction  The gripping story of Whoreson James, the son ...
# 4  9780060548285             The Wicked Day        Mary Stewart                    Fiction  Born of an incestuous relationship between Kin...
# 5  9780060975005        Gold Bug Variations      Richard Powers                    Fiction  A national bestseller, voted by Time as the #1...
# 6  9780060927547        Mr. Ives' Christmas      Oscar Hijuelos                    Fiction  Hijuelos' novel tells the story of Mr. Ives, w...
# 7  9780449911945             Rabbit at Rest         John Updike                    Fiction  Winner of the Pulitzer Prize, the Howells Meda...
# 8  9780786282258        The Lightning Thief        Rick Riordan           JUVENILE FICTION  After learning that he is the son of a mortal ...
# 9  9780060747220             Son of a Witch     Gregory Maguire                    Fiction  Ten years after the publication of Wicked, bel...
#
#    published_year  average_rating  num_pages  ratings_count
# 0          2004.0            3.85      247.0          361.0
# 1          2001.0            4.06      752.0         1785.0
# 2          1990.0            3.96      448.0          650.0
# 3          1972.0            4.33      320.0         1449.0
# 4          2003.0            4.09      417.0         9875.0
# 5          1992.0            4.13      640.0         1383.0
# 6          1996.0            3.76      256.0          912.0
# 7          1996.0            3.97      608.0        13038.0
# 8          2006.0            4.24      483.0          138.0
# 9          2006.0            3.47      352.0        51493.0

# %%
# explanation of similarities
response["hits"]["hits"]
# Out:
# [{'_shard': '[uppa_2025_dassance_kattin][0]',
#   '_node': 'w4J3bTfdQgWTrMMKXDMARw',
#   '_index': 'uppa_2025_dassance_kattin',
#   '_type': '_doc',
#   '_id': '7dCwT5QB5IuiTNqkUQzC',
#   '_score': 44.67813,
#   '_source': {'isbn13': 9780002005883,
#    'title': 'Gilead',
#    'authors': 'Marilynne Robinson',
#    'categories': 'Fiction',
#    'description': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#    'published_year': 2004.0,
#    'average_rating': 3.85,
#    'num_pages': 247.0,
#    'ratings_count': 361.0},
#   '_explanation': {'value': 44.67813,
#    'description': 'sum of:',
#    'details': [{'value': 1.0242417,
#      'description': 'weight(description:that in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.0242417,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.156219,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1610,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.5275877,
#      'description': 'weight(description:to in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.5275877,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5027689,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.1035992,
#      'description': 'weight(description:by in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.1035992,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.245802,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1472,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.5541134,
#      'description': 'weight(description:who in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.5541134,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.7543665,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 885,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.37647,
#      'description': 'weight(description:an in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.37647,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.2444448,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1474,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5027689,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.44887,
#      'description': 'weight(description:between in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.44887,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.764416,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 322,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.716721,
#      'description': 'weight(description:in in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.716721,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6275922,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.5724726,
#      'description': 'weight(description:best in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.5724726,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.9039452,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 280,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.9543164,
#      'description': 'weight(description:he in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.9543164,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.7668667,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 874,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5027689,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.8267908,
#      'description': 'weight(description:readers in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.8267908,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.1910334,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 210,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.4541676,
#      'description': 'weight(description:for in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.4541676,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.151264,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1618,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.57413876,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.4545953,
#      'description': 'weight(description:a in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.4545953,
#        'description': 'score(freq=7.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7023207,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 7.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.5303528,
#      'description': 'weight(description:story in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.5303528,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.2876523,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 519,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5027689,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.2856396,
#      'description': 'weight(description:of in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.2856396,
#        'description': 'score(freq=9.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7520709,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 9.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.4428923,
#      'description': 'weight(description:is in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.4428923,
#        'description': 'score(freq=6.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.9801782,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1920,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6691234,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 6.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 4.696659,
#      'description': 'weight(description:critics in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 4.696659,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 5.301841,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 25,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.2081534,
#      'description': 'weight(description:the in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.2081534,
#        'description': 'score(freq=13.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.81418145,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 13.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.7970701,
#      'description': 'weight(description:his in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.7970701,
#        'description': 'score(freq=7.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.1630727,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1599,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7023207,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 7.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.3175674,
#      'description': 'weight(description:and in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.3175674,
#        'description': 'score(freq=13.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.81418145,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 13.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 6.055497,
#      'description': 'weight(description:preacher in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 6.055497,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 6.835771,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 5,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.4026611,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 4.4970884,
#      'description': 'weight(description:john in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 4.4970884,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.560343,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 145,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.57413876,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 4.833266,
#      'description': 'weight(description:son in 423) [PerFieldSimilarity], result of:',
#      'details': [{'value': 4.833266,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8264945,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 111,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.57413876,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 200.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}},
#  {'_shard': '[uppa_2025_dassance_kattin][0]',
#   '_node': 'w4J3bTfdQgWTrMMKXDMARw',
#   '_index': 'uppa_2025_dassance_kattin',
#   '_type': '_doc',
#   '_id': 'W9CwT5QB5IuiTNqkQwUh',
#   '_score': 18.894234,
#   '_source': {'isbn13': 9780684813639,
#    'title': 'John Adams',
#    'authors': 'David McCullough',
#    'categories': 'Biography & Autobiography',
#    'description': 'In this powerful, epic biography, David McCullough unfolds the adventurous life-journey of John Adams, the brilliant, fiercely independent, often irascible, always honest Yankee patriot -- "the colossus of independence," as Thomas Jefferson called him -- who spared nothing in his zeal for the American Revolution; who rose to become the second President of the United States and saved the country from blundering into an unnecessary war; who was learned beyond all but a few and regarded by some as "out of his senses"; and whose marriage to the wise and valiant Abigail Adams is one of the moving love stories in American history. Like his masterly, Pulitzer Prize-winning biography Truman, David McCullough\'s John Adams has the sweep and vitality of a great novel. It is both a riveting portrait of an abundantly human man and a vivid evocation of his time, much of it drawn from an outstanding collection of Adams family letters and diaries. In particular, the more than one thousand surviving letters between John and Abigail Adams, nearly half of which have never been published, provide extraordinary access to their private lives and make it possible to know John Adams as no other major American of his founding era. As he has with stunning effect in his previous books, McCullough tells the story from within -- from the point of view of the amazing eighteenth century and of those who, caught up in events, had no sure way of knowing how things would turn out. George Washington, Benjamin Franklin, John Jay, the British spy Edward Bancroft, Madame Lafayette and Jefferson\'s Paris "interest" Maria Cosway, Alexander Hamilton, James Madison, the scandalmonger James Callender, Sally Hemings, John Marshall, Talleyrand, and Aaron Burr all figure in this panoramic chronicle, as does, importantly, John Quincy Adams, the adored son whom Adams would live to see become President. Crucial to the story, as it was to history, is the relationship between Adams and Jefferson, born opposites -- one a Massachusetts farmer\'s son, the other a Virginia aristocrat and slaveholder, one short and stout, the other tall and spare. Adams embraced conflict; Jefferson avoided it. Adams had great humor; Jefferson, very little. But they were alike in their devotion to their country. At first they were ardent co-revolutionaries, then fellow diplomats and close friends. With the advent of the two political parties, they became archrivals, even enemies, in the intense struggle for the presidency in 1800, perhaps the most vicious election in history. Then, amazingly, they became friends again, and ultimately, incredibly, they died on the same day -- their day of days -- July 4, in the year 1826. Much about John Adams\'s life will come as a surprise to many readers. His courageous voyage on the frigate Boston in the winter of 1778 and his later trek over the Pyrenees are exploits that few would have dared and that few readers will ever forget. It is a life encompassing a huge arc -- Adams lived longer than any president. The story ranges from the Boston Massacre to Philadelphia in 1776 to the Versailles of Louis XVI, from Spain to Amsterdam, from the Court of St. James\'s, where Adams was the first American to stand before King George III as a representative of the new nation, to the raw, half-finished Capital by the Potomac, where Adams was the first President to occupy the White House. This is history on a grand scale -- a book about politics and war and social issues, but also about human nature, love, religious faith, virtue, ambition, friendship and betrayal, and the far-reaching consequences of noble ideas. Above all, John Adams is an enthralling, often surprising story of one of the most important and fascinating Americans who ever lived.',
#    'published_year': 2001.0,
#    'average_rating': 4.06,
#    'num_pages': 752.0,
#    'ratings_count': 1785.0},
#   '_explanation': {'value': 18.894234,
#    'description': 'sum of:',
#    'details': [{'value': 0.49387717,
#      'description': 'weight(description:that in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.49387717,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.156219,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1610,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.19415838,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.67553127,
#      'description': 'weight(description:to in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.67553127,
#        'description': 'score(freq=15.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.4769838,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3176,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6437528,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 15.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.5321424,
#      'description': 'weight(description:by in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.5321424,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.245802,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1472,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.19415838,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.4508853,
#      'description': 'weight(description:who in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.4508853,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.7543665,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 885,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.37591535,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.89027166,
#      'description': 'weight(description:an in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.89027166,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.2444448,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1474,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.3251803,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.1808162,
#      'description': 'weight(description:between in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.1808162,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 2.764416,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 322,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.19415838,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.71693337,
#      'description': 'weight(description:in in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.71693337,
#        'description': 'score(freq=14.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.62777823,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 14.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.4179294,
#      'description': 'weight(description:he in 195) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.4179294,
#        'description': 'score(freq=1.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.7668667,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 874,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.107516825,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 1.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 600.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.3630452,
# ...
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.151876,
#      'description': 'weight(description:an in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.151876,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.2444448,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1474,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.42073375,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.84958863,
#      'description': 'weight(description:in in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.84958863,
#        'description': 'score(freq=8.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.51909864,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3045,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.7439369,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 8.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 2.6643486,
#      'description': 'weight(description:he in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 2.6643486,
#        'description': 'score(freq=6.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.7668667,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 874,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.6854323,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 6.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.0656264,
#      'description': 'weight(description:for in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.0656264,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.151264,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1618,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.42073375,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.33749786,
#      'description': 'weight(description:a in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.33749786,
#        'description': 'score(freq=3.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.29421633,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 3813,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5214127,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 3.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.27257922,
#      'description': 'weight(description:of in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.27257922,
#        'description': 'score(freq=7.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17263822,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4306,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.71768373,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 7.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.3905748,
#      'description': 'weight(description:is in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.3905748,
#        'description': 'score(freq=5.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.9801782,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1920,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.64486176,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 5.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.20794359,
#      'description': 'weight(description:the in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.20794359,
#        'description': 'score(freq=12.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.116208956,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4556,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.8133608,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 12.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 1.0765567,
#      'description': 'weight(description:his in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 1.0765567,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 1.1630727,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 1599,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.42073375,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 0.23101458,
#      'description': 'weight(description:and in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 0.23101458,
#        'description': 'score(freq=4.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 0.17729318,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 4286,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.5922767,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 4.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]},
#     {'value': 3.5418582,
#      'description': 'weight(description:son in 471) [PerFieldSimilarity], result of:',
#      'details': [{'value': 3.5418582,
#        'description': 'score(freq=2.0), computed as boost * idf * tf from:',
#        'details': [{'value': 2.2, 'description': 'boost', 'details': []},
#         {'value': 3.8264945,
#          'description': 'idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:',
#          'details': [{'value': 111,
#            'description': 'n, number of documents containing term',
#            'details': []},
#           {'value': 5117,
#            'description': 'N, total number of documents with field',
#            'details': []}]},
#         {'value': 0.42073375,
#          'description': 'tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:',
#          'details': [{'value': 2.0,
#            'description': 'freq, occurrences of term within document',
#            'details': []},
#           {'value': 1.2,
#            'description': 'k1, term saturation parameter',
#            'details': []},
#           {'value': 0.75,
#            'description': 'b, length normalization parameter',
#            'details': []},
#           {'value': 184.0,
#            'description': 'dl, length of field (approximate)',
#            'details': []},
#           {'value': 67.49267,
#            'description': 'avgdl, average length of field',
#            'details': []}]}]}]}]}}]

# %% [markdown]
# Le livre le plus similaire selon le contenu, l'auteur et le titre est le livre "John Adams" de David McCullough dans la catégorie "Biography & Autobiography", qui est noté à 4.06. Nous aurions donc fait une erreur de : 4.06 - 3.85 = 0.21

# %%
# @title Correction : pour aller plus loin une autre façon d'écrire la requête.

# Utiliser more_like_this pour construire un modèle de similarité
def more_like_this_model(book_id):
    response = es.search(index="books", body={
        "query": {
            "more_like_this": {
                "fields": ["title", "author", "description"],
                "like": [
                    {
                        "_index": "books",
                        "_id": book_id
                    }
                ],

                "min_term_freq": 1,
                "max_query_terms": 12
            }
        }
    })
    # Récupérer les informations relatives aux livres similaires
    similar_books_info = [hit['_source'] for hit in response['hits']['hits']]
    # [hit['_id'] for hit in response['hits']['hits']]
    return similar_books_info

# Tester la fonction more_like_this_model_with_info
book_id = "4896RpQB5IuiTNqk9FCO"  # Remplacez par l'ID d'un livre spécifique
similar_books_info = more_like_this_model(book_id)
print(f"Books similar to book {book_id}: {similar_books_info} \n")

# Afficher les informations sous forme de DataFrame
df_similar_books = pd.DataFrame(similar_books_info)
print(df_similar_books)
# Out:
# Books similar to book 4896RpQB5IuiTNqk9FCO: [{'thumbnail': 'http://books.google.com/books/content?id=GXWJDQAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_year': 1996, 'num_pages': 608, 'description': "Winner of the Pulitzer Prize, the Howells Medal, and the National Book Critics Circle Award In John Updike's fourth and final novel about Harry “Rabbit” Angstrom, the hero has acquired a Florida condo, a second grandchild, and a troubled, overworked heart. His son, Nelson, is behaving erratically; his daughter-in-law, Pru, is sending him mixed signals; and his wife, Janice, decides in midlife to return to the world of work. As, through the year of 1989, Reagan's debt-ridden, AIDS-plagued America yields to that of the first George Bush, Rabbit explores the bleak terrain of late middle age, looking for reasons to live and opportunities to make peace with a remorselessly accumulating past.", 'average_rating': 3.97, 'title': 'Rabbit at Rest', 'isbn13': 9780449911945, 'isbn10': '449911942', 'categories': 'Fiction', 'ratings_count': 13038, 'authors': 'John Updike'}, {'thumbnail': 'http://books.google.com/books/content?id=eyg78GsvB6UC&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_year': 2001, 'num_pages': 256, 'description': 'The story of the guilt, bitterness and spiritual strivings of the Grimes family which is told as the son, John, faces the issue of religious conversion in the Temple of the Fire Baptised.', 'average_rating': 4.01, 'title': 'Go Tell it on the Mountain', 'isbn13': 9780141185910, 'isbn10': '141185910', 'categories': 'Fiction', 'ratings_count': 33558, 'authors': 'James Baldwin'}, {'thumbnail': 'http://books.google.com/books/content?id=ws5LJwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_year': 1997, 'num_pages': 160, 'description': "/Garth Ennis /Steven Dillon and Glenn Fabry From the writer and artist of PREACHER, John Constantine is a cynical, hard drinking chain smoking Brit who's been around the block a few times and occasionally saved the world with his magical savvy. In this volume, Constantine must prevent his young niece from following in his mystic footsteps, cope with his own 40th birthday, attended by Swamp Thing and other mystical guests, and engineer the fall from heaven", 'average_rating': 4.17, 'title': 'John Constantine, Hellblazer', 'isbn13': 9781563892028, 'subtitle': 'Fear and Loathing', 'isbn10': '1563892022', 'categories': 'Comics & Graphic Novels', 'ratings_count': 3375, 'authors': 'Garth Ennis;Steve Dillon'}, {'thumbnail': 'http://books.google.com/books/content?id=03tee7J8wBwC&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_year': 2004, 'num_pages': 337, 'description': 'Macon Dead, Jr., called "Milkman," the son of the wealthiest African American in town, moves from childhood into early manhood, searching, among the disparate, mysterious members of his family, for his life and reality. Winner of the National Book Critics Circle Award. Reader\'s Guide available. Reprint. 50,000 first printing.', 'average_rating': 4.04, 'title': 'Song of Solomon', 'isbn13': 9781400033423, 'isbn10': '140003342X', 'categories': 'Fiction', 'ratings_count': 69036, 'authors': 'Toni Morrison'}, {'thumbnail': 'http://books.google.com/books/content?id=D__PpFsJLvoC&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_year': 1972, 'num_pages': 320, 'description': "The gripping story of Whoreson James, the son of a beautiful black prostitute and an unknown john. Corrupted by the violent Ghetto world, at the age of sixteen he is a fully fledged pimp: cold blooded and ruthless. A startling insight into the mean streets of the tough inner city by America's number one author of the genre.", 'average_rating': 4.33, 'title': 'Whoreson', 'isbn13': 9780870679940, 'subtitle': 'The Story of a Ghetto Pimp', 'isbn10': '870679945', 'categories': 'Fiction', 'ratings_count': 1449, 'authors': 'Donald Goines'}, {'thumbnail': 'http://books.google.com/books/content?id ...
#
#                                            thumbnail  published_year  num_pages                                        description  average_rating  \
# 0  http://books.google.com/books/content?id=GXWJD...            1996        608  Winner of the Pulitzer Prize, the Howells Meda...            3.97
# 1  http://books.google.com/books/content?id=eyg78...            2001        256  The story of the guilt, bitterness and spiritu...            4.01
# 2  http://books.google.com/books/content?id=ws5LJ...            1997        160  /Garth Ennis /Steven Dillon and Glenn Fabry Fr...            4.17
# 3  http://books.google.com/books/content?id=03tee...            2004        337  Macon Dead, Jr., called "Milkman," the son of ...            4.04
# 4  http://books.google.com/books/content?id=D__Pp...            1972        320  The gripping story of Whoreson James, the son ...            4.33
# 5  http://books.google.com/books/content?id=Hsdtr...            2006        455  This collection of 59 essays--comprising the f...            3.50
# 6  http://books.google.com/books/content?id=bHxyr...            2002        240  Cry the Beloved Country is the deeply moving s...            3.89
# 7  http://books.google.com/books/content?id=1XmQt...            1996        464  The story of an Egyptian family mirrors the sp...            4.10
# 8  http://books.google.com/books/content?id=s28MA...            2006         46  Describes the construction of the Brooklyn Bri...            4.44
# 9  http://books.google.com/books/content?id=13k-l...            1998        306  0ne of the most feisty, spellbinding and engag...            3.91
#
#                           title         isbn13      isbn10               categories  ratings_count                         authors  \
# 0                Rabbit at Rest  9780449911945   449911942                  Fiction          13038                     John Updike
# 1    Go Tell it on the Mountain  9780141185910   141185910                  Fiction          33558                   James Baldwin
# 2  John Constantine, Hellblazer  9781563892028  1563892022  Comics & Graphic Novels           3375        Garth Ennis;Steve Dillon
# 3               Song of Solomon  9781400033423  140003342X                  Fiction          69036                   Toni Morrison
# 4                      Whoreson  9780870679940   870679945                  Fiction           1449                   Donald Goines
# 5         The John Adams Reader  9781574671322  1574671324                    Music             20               Thomas Robert May
# 6      Cry, the Beloved Country  9780099766810    99766817        Classical fiction            729                      Alan Paton
# 7         Children of the Alley  9780385264730   385264739                  Fiction           1124                    Najīb Maḥfūẓ
# 8           The Brooklyn Bridge  9781931414166  1931414165      Juvenile Nonfiction             35  Elizabeth Mann;Alan Witschonke
# 9                   Kate Vaiden  9780684846941   684846942                  Fiction           1313                  Reynolds Price
#
#                                      subtitle
# 0                                         NaN
# 1                                         NaN
# 2                           Fear and Loathing
# 3                                         NaN
# 4                  The Story of a Ghetto Pimp
# 5  Essential Writings on an American Composer
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN

# %% [markdown]
# ### Correction : pour aller plus loin
# Recherche des termes avec un second modèle `multi_match`
# Documentation : https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-multi-match-query.html

# %%
###############################################    Apply the multi_match function

response = es.search(index="uppa_2025_train_dassance_kattin", body={
    "query": {
        "multi_match": {
            "query": "A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.",
            "fields": ["description"]
        }
    }
})

print(response)
hits = response['hits']['hits']
source_list = [hit['_source'] for hit in hits]
df = pd.json_normalize(source_list)
print(df)
# Out:
# {'took': 85, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 5072, 'relation': 'eq'}, 'max_score': 479.51166, 'hits': [{'_index': 'uppa_2025_dassance_kattin', '_type': '_doc', '_id': '7dCwT5QB5IuiTNqkUQzC', '_score': 479.51166, '_source': {'isbn13': 9780002005883, 'title': 'Gilead', 'authors': 'Marilynne Robinson', 'categories': 'Fiction', 'description': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.', 'published_year': 2004.0, 'average_rating': 3.85, 'num_pages': 247.0, 'ratings_count': 361.0}}, {'_index': 'uppa_2025_dassance_kattin', '_type': '_doc', '_id': 'W9CwT5QB5IuiTNqkQwUh', '_score': 89.008675, '_source': {'isbn13': 9780684813639, 'title': 'John Adams', 'authors': 'David McCullough', 'categories': 'Biography & Autobiography', 'description': 'In this powerful, epic biography, David McCullough unfolds the adventurous life-journey of John Adams, the brilliant, fiercely independent, often irascible, always honest Yankee patriot -- "the colossus of independence," as Thomas Jefferson called him -- who spared nothing in his zeal for the American Revolution; who rose to become the second President of the United States and saved the country from blundering into an unnecessary war; who was learned beyond all but a few and regarded by some as "out of his senses"; and whose marriage to the wise and valiant Abigail Adams is one of the moving love stories in American history. Like his masterly, Pulitzer Prize-winning biography Truman, David McCullough\'s John Adams has the sweep and vitality of a great novel. It is both a riveting portrait of an abundantly human man and a vivid evocation of his time, much of it drawn from an outstanding collection of Adams family letters and diaries. In particular, the more than one thousand surviving letters between John and Abigail Adams, nearly half of which have never been published, provide extraordinary access to their private lives and make it possible to know John Adams as no other major American of his founding era. As he has with stunning effect in his previous books, McCullough tells the story from within -- from the point of view of the amazing eighteenth century and of those who, caught up in events, had no sure way of knowing how things would turn out. George Washington, Benjamin Franklin, John Jay, the British spy Edward Bancroft, Madame Lafayette and Jefferson\'s Paris "interest" Maria Cosway, Alexander Hamilton, James Madison, the scandalmonger James Callender, Sally Hemings, John Marshall, Talleyrand, and Aaron Burr all figure in this panoramic chronicle, as does, importantly, John Quincy Adams, the adored son whom Adams would live to see become President. Crucial to the story, as it was to history, is the relationship between Adams and Jefferson, born opposites -- one a Massachusetts farmer\'s son, the other a Virginia arist ...
#           isbn13                      title                                            authors                           categories  \
# 0  9780002005883                     Gilead                                 Marilynne Robinson                              Fiction
# 1  9780684813639                 John Adams                                   David McCullough            Biography & Autobiography
# 2  9780449911945             Rabbit at Rest                                        John Updike                              Fiction
# 3  9780060927547        Mr. Ives' Christmas                                     Oscar Hijuelos                              Fiction
# 4  9780803283855           Black Elk Speaks  Black Elk;John Gneisenau Neihardt;Alexis N. Pe...            Biography & Autobiography
# 5  9780060747220             Son of a Witch                                    Gregory Maguire                              Fiction
# 6  9780743270793               Untouchables                                    Narendra Jadhav            Biography & Autobiography
# 7  9780743496162        Never Go Home Again                                     Shannon Holmes                              Fiction
# 8  9780060916817  The Chaneysville Incident                                      David Bradley                              History
# 9  9780552998680          My Movie Business                                        John Irving  Cider house rules. (Motion picture)
#
#                                          description  published_year  average_rating  num_pages  ratings_count
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0            3.85      247.0          361.0
# 1  In this powerful, epic biography, David McCull...          2001.0            4.06      752.0         1785.0
# 2  Winner of the Pulitzer Prize, the Howells Meda...          1996.0            3.97      608.0        13038.0
# 3  Hijuelos' novel tells the story of Mr. Ives, w...          1996.0            3.76      256.0          912.0
# 4  Black Elk Speaks is the story of the Lakota vi...          2004.0            4.14      270.0         9916.0
# 5  Ten years after the publication of Wicked, bel...          2006.0            3.47      352.0        51493.0
# 6  Every sixth human being in the world today is ...          2005.0            3.82      320.0          299.0
# 7  The experience and quality that I bring to my ...          2005.0            4.04      320.0          217.0
# 8  The legends say something happened in Chaneysv...          1990.0            3.96      448.0          650.0
# 9  John Irving's memoir begins with his account o...          2000.0            3.33      158.0           26.0

# %% [markdown]
# ## Question 2

# %%
def get_similar_document(row):
    # Extraire les informations pertinentes de la ligne du dataframe
    title = row['title']
    author = row['authors']
    description = row['description']

    # Requête more_like_this pour Elasticsearch
    response = es.search(index="uppa_2025_train_dassance_kattin", body={
        "query": {
            "more_like_this": {
                "fields": ["title", "authors", "description"],
                "like": f"{title} {author} {description}"
            }
        },
        "explain": "true"
    })

    # Récupérer les documents similaires
    hits = response['hits']['hits']

    if hits:
        # Extraire les informations du premier résultat le plus pertinent
        most_similar_doc = hits[0]['_source']
        # Renvoyer la valeur de la colonne 'average_rating'
        return most_similar_doc.get('average_rating', None)
    else:
        return None

# %%
test_df['similar_average_rating'] = test_df.apply(get_similar_document, axis=1)

# %%
# compute metrics
mae = np.mean(np.abs(test_df['similar_average_rating'] - test_df['average_rating']))
print(f"Erreur absolue moyenne (MAE) : {mae}")

mse = np.mean((test_df['similar_average_rating'] - test_df['average_rating']) ** 2)
print(f"Erreur quadratique moyenne (MSE) : {mse}")

rmse = np.sqrt(mse)
print(f"Racine de l'erreur quadratique moyenne (RMSE) : {rmse}")
# Out:
# Erreur absolue moyenne (MAE) : 0.28680250783699063
# Erreur quadratique moyenne (MSE) : 0.17300156739811912
# Racine de l'erreur quadratique moyenne (RMSE) : 0.4159345710542935

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Détection de la langue

# %%
# Fonction pour détecter la langue d'un titre de livre
def detect_language(description):
    try:
        return detect(description)
    except:
        return 'unknown'

# %%
# Ajouter une colonne 'language' au DataFrame
train_df['language'] = train_df['description'].apply(detect_language)
test_df['language'] = test_df['description'].apply(detect_language)

# %%
train_df.head(2)
# Out:
#                                               thumbnail  published_year  num_pages                                        description  \
# 4235  http://books.google.com/books/content?id=W3dGP...          1992.0      288.0                                                NaN
# 6602  http://books.google.com/books/content?id=8ClIP...          2000.0      288.0  In the year 2100, mankind on Earth, settlers i...
#
#       average_rating                title         isbn13      isbn10       categories  ratings_count          authors subtitle language
# 4235            3.93        The Egg and I  9780704102477   704102471        Farm life         6223.0  Betty MacDonald      NaN  unknown
# 6602            4.09  The Gods Themselves  9781857989342  1857989341  Science fiction        41304.0     Isaac Asimov      NaN       en

# %%
# Vérifier la distribution des langues
print(train_df['language'].value_counts())
# Out:
# language
# en         5199
# unknown     220
# de           10
# id            8
# nl            3
# da            2
# vi            1
# af            1
# tl            1
# sl            1
# ja            1
# ro            1
# Name: count, dtype: int64

# %%
for index, row in train_df.iterrows():
    id_book = row['isbn13']  # ID du document dans Elasticsearch
    language = row['language']  # Langue à mettre à jour

    # Utiliser update_by_query pour mettre à jour le champ 'language'
    update_query = {
        "script": {
            "source": "ctx._source.language = params.language",
            "params": {
                "language": language
            }
        },
        "query": {
            "term": {
                "isbn13": id_book  # Filtrer sur id_book
            }
        }
    }

    # Exécuter la requête
    response = es.update_by_query(index="uppa_2025_train_dassance_kattin", body=update_query)

    print(f"Updated language for id_book {id_book}: {language}. Response: {response}")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Updated language for id_book 9780099481249: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780192833594: en. Response: {'took': 14, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446600347: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780374280390: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446676502: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780739422953: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780340820469: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780064408745: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780385335102: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780618619078: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781887726092: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780553381696: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781892391360: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780671732523: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140259100: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780674992184: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780143035169: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780801868221: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780226307800: en. Response: {'took': 13, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780520206397: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312279998: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780380731954: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312330866: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780786937790: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780743227193: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345463098: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780394759845: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781569708859: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780521348881: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780393964523: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781570625190: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780802130167: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780226424156: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780029131695: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780743297264: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780261102637: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781565482340: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446600705: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780553275674: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780878056262: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780141304311: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060922559: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781451640175: en. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780425199169: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780767909266: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781406957242: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780141310695: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781593077365: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312874568: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780765316110: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060976101: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780743210768: en. Response: {'took': 14, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781421500911: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780521750844: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780393318791: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780552998833: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140264920: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140363333: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060837167: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780946061150: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781931082303: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060882815: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780747566755: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345450692: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780618477944: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780441014835: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780439651394: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780822218630: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780618083558: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780439176835: en. Response: {'took': 10, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781573225052: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345377968: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780451412119: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780374530495: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312997830: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780434009053: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780767912242: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781400079858: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060564780: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780679600053: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780007151240: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780805069860: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140238280: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780061122095: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780143030904: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780380711963: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780525947264: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780451209795: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140281705: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781400064892: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780198752752: en. Response: {'took': 12, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780316769488: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780425169698: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780805078985: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446695671: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780486292724: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781860469015: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781588467980: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781741042955: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780679428954: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780373771721: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780192837622: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780330314916: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780571206926: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781593080037: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780156006248: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780573612251: unknown. Response: {'took': 2, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781567430288: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780743272933: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312990695: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780671015206: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345463159: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780515128550: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780751504385: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312970741: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780142003718: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446605588: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780785124979: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780373126002: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781595820617: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780064405713: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781579652524: en. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781556434303: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060928414: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446362665: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781597818704: en. Response: {'took': 9, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781891620416: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446524124: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780141185118: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780143037231: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780007120697: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780618471164: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781416532354: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780261102422: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780061159176: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780515140873: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780143039495: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780310929550: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345456342: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780679785897: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780515141672: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780340637876: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780842383677: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781582344720: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780674673779: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780340796313: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780679733782: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780486406640: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780679890706: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780451160317: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780143038825: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140449495: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# ...
# Updated language for id_book 9780140059021: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780671820121: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780553588118: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780486431673: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780312352356: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780199267170: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345477385: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780762408283: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780451210845: en. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780439856263: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060572006: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780345412812: en. Response: {'took': 13, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780142003343: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780439994798: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780374529383: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780425144305: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780152052607: en. Response: {'took': 7, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780064400992: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446673785: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780786016068: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781593080235: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780684848150: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780552997775: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780751506006: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780192822895: en. Response: {'took': 8, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781594481772: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780805212075: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780823078943: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780393924954: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780960989867: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780393311396: en. Response: {'took': 4, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140367430: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780321432872: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780060175641: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780446696616: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780486272665: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780553279375: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781580931779: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780933121294: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780743461511: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780826514707: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780062511119: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781583421543: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9781400047864: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780452281257: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780618615384: unknown. Response: {'took': 1, 'timed_out': False, 'total': 0, 'updated': 0, 'deleted': 0, 'batches': 0, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780812574739: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780812971422: en. Response: {'took': 6, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780844667508: en. Response: {'took': 5, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}
# Updated language for id_book 9780140621624: en. Response: {'took': 9, 'timed_out': False, 'total': 1, 'updated': 1, 'deleted': 0, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}

# %% [markdown]
# ### Evaluation de la similarité

# %%
def get_similar_document_by_language(row):
    # Extraire les informations pertinentes de la ligne du dataframe
    title = row['title']
    authors = row['authors']
    description = row['description']
    language = row['language']

    # Requête more_like_this pour Elasticsearch, en incluant un filtre sur la langue
    response = es.search(index="uppa_2025_train_dassance_kattin", body={
        "query": {
            "bool": {
                "must": {
                    "more_like_this": {
                        "fields": ["title", "authors", "description"],
                        "like": f"{title} {authors} {description}"
                    }
                },
                "filter": {
                    "term": {
                        "language": language  # Filtrer par langue
                    }
                }
            }
        },
        "explain": "true"
    })

    # Récupérer les documents similaires
    hits = response['hits']['hits']

    if hits:
        # Extraire les informations du premier résultat le plus pertinent
        most_similar_doc = hits[0]['_source']
        # Renvoyer la valeur de la colonne 'average_rating'
        return most_similar_doc.get('average_rating', None)
    else:
        return None

# %%
test_df['lang_similar_average_rating'] = test_df.apply(get_similar_document_by_language, axis=1)

# Afficher le dataframe avec la nouvelle colonne 'lang_similar_average_rating'
print(test_df.head())
# Out:
#                                               thumbnail  published_year  num_pages                                        description  \
# 1632  http://books.google.com/books/content?id=dTHrm...          2004.0      528.0  According to the DC cops, the fiery destructio...
# 3891  http://books.google.com/books/content?id=ozQ8R...          1958.0      260.0  A story of a Chinese peasant and his passionat...
# 2115  http://books.google.com/books/content?id=E-GwA...          1993.0      185.0  In a world marked by full-scale neighborhood w...
# 2404  http://books.google.com/books/content?id=LUrJI...          2001.0      256.0  This two-part profile of the late Nobel Prize-...
# 3260  http://books.google.com/books/content?id=HGrNS...          1994.0      720.0  Fans of Jurassic Park and Rising Sun, the book...
#
#       average_rating                                        title         isbn13     isbn10                 categories  ratings_count  \
# 1632            3.76                                  The Firefly  9780312994815  312994818                    Fiction          301.0
# 3891            3.98                               The Good Earth  9780671823498  671823493                      China           54.0
# 2115            3.67        Elect Mr. Robinson for a Better World  9780375725036  375725032                    Fiction          795.0
# 2404            4.27  "What Do You Care what Other People Think?"  9780393320923  393320928  BIOGRAPHY & AUTOBIOGRAPHY        15646.0
# 3260            3.99    A New Collection of Three Complete Novels  9780517101353  517101351                    Fiction          943.0
#
#                                       authors                                   subtitle  similar_average_rating language  \
# 1632                         P. T. Deutermann                                    A Novel                    3.56       en
# 3891                 Pearl Sydenstricker Buck                                        NaN                    4.21       en
# 2115                            Donald Antrim                                        NaN                    3.85       en
# 2404  Richard Phillips Feynman;Ralph Leighton  Further Adventures of a Curious Character                    4.41       en
# 3260                         Michael Crichton                                        NaN                    4.15       en
#
#       lang_similar_average_rating
# 1632                         3.73
# 3891                         4.21
# 2115                         3.85
# 2404                         4.41
# 3260                         4.15

# %%
# compute metrics
mae = np.mean(np.abs(test_df['lang_similar_average_rating'] - test_df['average_rating']))
print(f"Erreur absolue moyenne (MAE) : {mae}")

mse = np.mean((test_df['lang_similar_average_rating'] - test_df['average_rating']) ** 2)
print(f"Erreur quadratique moyenne (MSE) : {mse}")

rmse = np.sqrt(mse)
print(f"Racine de l'erreur quadratique moyenne (RMSE) : {rmse}")
# Out:
# Erreur absolue moyenne (MAE) : 0.28802683504340965
# Erreur quadratique moyenne (MSE) : 0.17682186266771902
# Racine de l'erreur quadratique moyenne (RMSE) : 0.4205019175553413
